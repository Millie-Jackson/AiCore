# %%
import cv2
from keras.models import load_model
import numpy as np
from random import *
model = load_model('C:/Users/Millie/Documents/AiCore/Model/keras_model.h5', compile=False)
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

#while True: 
#    ret, frame = cap.read()
#    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
#    image_np = np.array(resized_frame)
#    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#    data[0] = normalized_image
#    prediction = model.predict(data)
#    cv2.imshow('frame', frame)
running = True
def game():
#ask for user input and count down from 3
#cap = cv2.VideoCapture(0)
    name = input("Hi, want to play? Whats your name? ")
    print(name, "vs Computer")
#range(3, 0, -1)
    print("Ready? Ok")
    print("Rock")
    print("Paper")
    print("Scissors")
    print("GO!")
#playerGuess = input(cv2.VideoCapture(0))

#randomly select a position to play
    number = random()
    if number < 0.3:
        pcGuess = "Rock"
    elif number > 0.6:
        pcGuess = "Paper"
    else: pcGuess = "Scissors"

#print selected position
#print("You played ", playerGuess)
    print("I played ", pcGuess)

#compare positions
    playerGuess = "Rock"
    score = 0

    if playerGuess== 'Rock' and pcGuess== 'Scissors' or playerGuess== 'Scissors' and pcGuess== 'Paper' or playerGuess== 'Paper' and pcGuess== 'Rock':
        print("You Win!")
        score + 1
    else: 
        print("You Lose!")
        score - 1
    print("Score: ", score)
#show score
#while True:
#    print("Score:", score)

    input("Hi, want to play again? Or type 'no' to leave")
    #if cv2.waitKey(1) & 0xFF == ord('q'):
    if input== 'no':
        running = False

# Print predictions
    #if prediction[0][0] > 0.5:
    #    playerGuess = "Rock"
     #   print(playerGuess)
    #elif prediction[0][1] > 0.5:
    #    playerGuess = "Paper"
    #    print(playerGuess)
    #elif prediction[0][2] > 0.5:
    #    playerGuess = "Scissors"
    #    print(playerGuess)
    #else: 
    #    prediction[0][3] > 0.5
    #    plyerGuess = "Waiting..."
    #    print(playerGuess)
    
    #print(prediction)

while running:
    game()

    # Press q to close the window
input("Hi, want to play again? Or type 'no' to leave")
#if cv2.waitKey(1) & 0xFF == ord('q'):
running = False
            
# After the loop release the cap object
cap.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# kljoi vs Computer
# Ready? Ok
# Rock
# Paper
# Scissors
# GO!
# I played  Paper
# You Lose!
# Score:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6632/2380870049.py in <module>
#      84
#      85 while running:
# ---> 86     game()
#      87
#      88     # Press q to close the window
#
# ~\AppData\Local\Temp/ipykernel_6632/2380870049.py in game()
#      19 #ask for user input and count down from 3
#      20 #cap = cv2.VideoCapture(0)
# ---> 21     name = input("Hi, want to play? Whats your name? ")
#      22     print(name, "vs Computer")
#      23 #range(3, 0, -1)
#
# ~\miniconda3\envs\RPSProject\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\miniconda3\envs\RPSProject\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
